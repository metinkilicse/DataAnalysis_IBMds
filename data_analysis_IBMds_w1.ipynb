# %%
import pandas as pd

df = pd.read_csv('car_details_ford_focus.csv') # read_json(), read_excel(), read_sql()

# %%
df.head() # df.tail()
# Out:
#           id          date brand  serie                  model  year  \
# 0  784949216  28 ocak 2020  ford  focus  1.6 ti-vct titanium x  2009
# 1  784919763  28 ocak 2020  ford  focus    1.6 ti-vct titanium  2012
# 2  784789340  28 ocak 2020  ford  focus    1.6 ti-vct titanium  2014
# 3  784791962  28 ocak 2020  ford  focus          1.6 tdci ghia  2006
# 4  784548131  27 ocak 2020  ford  focus       1.8 tdci comfort  2003
#
#            fuel   transmission     km   type  ...      color  guarantee  \
# 0  benzin & lpg         manuel  210.0  sedan  ...       füme      hayır
# 1        benzin  yarı otomatik   94.0  sedan  ...      beyaz       evet
# 2        benzin  yarı otomatik  136.0  sedan  ...        gri      hayır
# 3         dizel         manuel  190.0  sedan  ...      beyaz      hayır
# 4         dizel         manuel  281.0  sedan  ...  gümüş gri      hayır
#
#                  Nation from_whome change      status  price      city  \
# ...

# %%
# if you don't have headers on file
headers = [
        "id", "date", "brand", "serie", "model", "year", "fuel",
        "transmission", "km", "type", "hp", "cc", "traction",
        "color", "guarantee", "Nation", "from_whome",
        "change", "status", "price","city","county","neighborhood"]
df.columns = headers
df.to_csv('output.csv') # to save df

# %%
# Basic Insights
# Data Types, # Data distribution
df.columns
# Out:
# Index(['id', 'date', 'brand', 'serie', 'model', 'year', 'fuel', 'transmission',
#        'km', 'type', 'hp', 'cc', 'traction', 'color', 'guarantee', 'Nation',
#        'from_whome', 'change', 'status', 'price', 'city', 'county',
#        'neighborhood'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                int64
# date             object
# brand            object
# serie            object
# model            object
# year              int64
# fuel             object
# transmission     object
# km              float64
# type             object
# hp                int64
# cc                int64
# traction         object
# color            object
# guarantee        object
# Nation           object
# from_whome       object
# change           object
# status           object
# price           float64
# city             object
# county           object
# neighborhood     object
# dtype: object

# %%
df.describe()
# Out:
#                  id         year          km          hp           cc  \
# count  8.270000e+02   827.000000  827.000000  827.000000   827.000000
# mean   7.806542e+08  2011.243047  151.861325  107.729141  1562.443773
# std    1.819330e+07     4.954044   74.447653   11.418271    71.577606
# min    5.427586e+08  1999.000000    7.800000   88.000000   999.000000
# 25%    7.841934e+08  2008.000000   93.269000   95.000000  1560.000000
# 50%    7.845501e+08  2012.000000  147.000000  110.000000  1560.000000
# 75%    7.848526e+08  2015.000000  195.000000  120.000000  1596.000000
# max    7.849938e+08  2019.000000  582.000000  138.000000  2750.000000
#
#             price
# count  827.000000
# mean    81.666496
# std     31.140675
# min     25.000000
# 25%     53.500000
# 50%     81.000000
# 75%    107.000000
# max    198.750000

# %%
df.describe(include='all')
# Out:
#                   id          date brand  serie             model  \
# count   8.270000e+02           827   827    827               827
# unique           NaN            20     1      1                34
# top              NaN  28 ocak 2020  ford  focus  1.6 tdci trend x
# freq             NaN           408   827    827               178
# mean    7.806542e+08           NaN   NaN    NaN               NaN
# std     1.819330e+07           NaN   NaN    NaN               NaN
# min     5.427586e+08           NaN   NaN    NaN               NaN
# 25%     7.841934e+08           NaN   NaN    NaN               NaN
# 50%     7.845501e+08           NaN   NaN    NaN               NaN
# 75%     7.848526e+08           NaN   NaN    NaN               NaN
# max     7.849938e+08           NaN   NaN    NaN               NaN
#
#                year   fuel transmission          km   type  ...  color  \
# count    827.000000    827          827  827.000000    827  ...    827
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             id          date brand  serie                  model  year  \
# 0    784949216  28 ocak 2020  ford  focus  1.6 ti-vct titanium x  2009
# 1    784919763  28 ocak 2020  ford  focus    1.6 ti-vct titanium  2012
# 2    784789340  28 ocak 2020  ford  focus    1.6 ti-vct titanium  2014
# 3    784791962  28 ocak 2020  ford  focus          1.6 tdci ghia  2006
# 4    784548131  27 ocak 2020  ford  focus       1.8 tdci comfort  2003
# ..         ...           ...   ...    ...                    ...   ...
# 822  784886305  28 ocak 2020  ford  focus          1.6 tdci ghia  2006
# 823  784132523  26 ocak 2020  ford  focus         1.6 collection  2005
# 824  782414495  28 ocak 2020  ford  focus       1.6 tdci trend x  2015
# 825  784415008  28 ocak 2020  ford  focus    1.6 tdci titanium x  2009
# 826  781353281  28 ocak 2020  ford  focus       1.6 tdci trend x  2017
#
#              fuel   transmission     km              type  ...      color  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            827 non-null    int64
#  1   date          827 non-null    object
#  2   brand         827 non-null    object
#  3   serie         827 non-null    object
#  4   model         827 non-null    object
#  5   year          827 non-null    int64
#  6   fuel          827 non-null    object
#  7   transmission  827 non-null    object
#  8   km            827 non-null    float64
#  9   type          827 non-null    object
#  10  hp            827 non-null    int64
#  11  cc            827 non-null    int64
#  12  traction      827 non-null    object
#  13  color         827 non-null    object
#  14  guarantee     827 non-null    object
#  15  Nation        827 non-null    object
#  16  from_whome    827 non-null    object
#  17  change        827 non-null    object
# ...

# %%
df[['year', 'hp', 'price']].describe()
# Out:
#               year          hp       price
# count   827.000000  827.000000  827.000000
# mean   2011.243047  107.729141   81.666496
# std       4.954044   11.418271   31.140675
# min    1999.000000   88.000000   25.000000
# 25%    2008.000000   95.000000   53.500000
# 50%    2012.000000  110.000000   81.000000
# 75%    2015.000000  120.000000  107.000000
# max    2019.000000  138.000000  198.750000
